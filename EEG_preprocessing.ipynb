# %%
#importing Google Drive 
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/ICA preprocessed.csv')

# %%
df.head()
# Out:
#     Time  TIME_STAMP_s  TIME_STAMP_ms  OR_TIME_STAMP_s  OR_TIME_STAMP_ms  \
# 0    0.0           0.0            0.0              0.0             172.0
# 1   62.5           0.0           62.5              0.0             235.0
# 2  125.0           0.0          125.0              0.0             298.0
# 3  187.5           0.0          187.5              0.0             360.0
# 4  250.0           0.0          250.0              0.0             423.0
#
#    COUNTER_MEMS  INTERPOLATED_MEM     Q0      Q1      Q2      Q3    ACCX  \
# 0          15.0               0.0  0.745  0.1837  0.2773  0.5782  0.9258
# 1           0.0               0.0  0.742  0.1837  0.2773  0.5820  0.9455
# 2           1.0               0.0  0.745  0.1837  0.2773  0.5782  0.9415
# 3           2.0               0.0  0.742  0.1837  0.2773  0.5820  0.9377
# 4           3.0               0.0  0.742  0.1837  0.2773  0.5820  0.9180
#
#      ACCY    ACCZ     MAGX     MAGY
# 0  0.2695  0.0468 -50.1667 -11.6667
# ...

# %%
pip install eeglib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.4 MB 16.3 MB/s
# ...

# %%
from eeglib import wrapper, helpers

helper = helpers.CSVHelper("/content/drive/My Drive/ICA preprocessed.csv", windowSize=128)

wrap = wrapper.Wrapper(helper)

wrap.addFeature.HFD()
wrap.addFeature.DFT()
wrap.addFeature.synchronizationLikelihood()

features=wrap.getAllFeatures()

# %%
features
# Out:
#            HFD(){}_0  HFD(){}_1  HFD(){}_2  HFD(){}_3  HFD(){}_4  HFD(){}_5  \
# window_id
# 0           1.144215   1.112688   2.645478   1.118520   2.482347   2.634132
# 1           1.144215   1.112688   2.643397   1.129882   2.588947   2.634132
# 2           1.144215   1.112688   2.644722   1.129882   2.446138   2.634132
# 3           1.144215   1.112688   2.645034   1.121657   2.336801   2.634132
# 4           1.144215   1.112688   2.645045   1.129882   2.443677   2.634132
# 5           1.144215   1.112688   2.643935   1.129882   2.610568   2.634132
# 6           1.144215   1.112688   2.643836   1.129882   2.412705   2.634132
#
#            HFD(){}_6  HFD(){}_7  HFD(){}_8  HFD(){}_9  ...  \
# window_id                                              ...
# 0           2.093947   1.942691   1.235247   2.075661  ...
# 1           2.326408   1.973454   1.560396   1.587551  ...
# 2           2.370520   2.415227   0.801450   1.982897  ...
# ...
